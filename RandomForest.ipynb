# %%
class H:
    def __init__(self):
        self.a = 1
        self.b = 2
    def __getitem__(self, key):
        print(key)
        i.__dict__[key] = "nuevo"

# %%
i = H()

# %%
i["hola"]
# Out:
# hola

# %%
i.hola
# Out:
# 'nuevo'

# %%
i.__dict__
# Out:
# {'a': 1, 'b': 2, 'hola': 'nuevo'}

# %%
for elem in i.__dict__:
        print(elem)
        print(i.__dict__[elem])
# Out:
# a
# 1
# b
# 2
# hola
# nuevo

# %%
import pandas as pd
headers = ["name","landmass","zone","area","population","language","religion","bars","stripes","colours","red","green","blue","gold","white","black","orange","mainhue","circles","crosses","saltires","quarters","sunstars","crescent","triangle","icon","animate","text","topleft","botright"]
tabla = pd.read_csv("resource/flag.data",names=headers)

# %%
tabla[(tabla["landmass"] == 5) & (tabla["name"] =="Afghanistan")]
# Out:
#           name  landmass  zone  area  population  language  religion  bars  \
# 0  Afghanistan         5     1   648          16        10         2     0
#
#    stripes  colours    ...     saltires  quarters  sunstars  crescent  \
# 0        3        5    ...            0         0         1         0
#
#    triangle  icon  animate text  topleft  botright
# 0         0     1        0    0    black     green
#
# [1 rows x 30 columns]

# %%
tabla[(tabla["landmass"] == 5)]
# Out:
#                 name  landmass  zone   area  population  language  religion  \
# 0        Afghanistan         5     1    648          16        10         2
# 13           Bahrain         5     1      1           0         8         2
# 14        Bangladesh         5     1    143          90         6         2
# 20            Bhutan         5     1     47           1        10         3
# 25            Brunei         5     1      6           0        10         2
# 28             Burma         5     1    678          35        10         3
# 37             China         5     1   9561        1008         7         6
# 78         Hong-Kong         5     1      1           5         7         3
# 81             India         5     1   3268         684         6         4
# 83              Iran         5     1   1648          39         6         2
# 84              Iraq         5     1    435          14         8         2
# ...

# %%
len(tabla[(tabla["landmass"] == 5)])
# Out:
# 39

# %%
tabla.sample(n=4)
# Out:
#            name  landmass  zone  area  population  language  religion  bars  \
# 135     Parguay         2     3   407           3         2         0     0
# 37        China         5     1  9561        1008         7         6     0
# 116  Montserrat         1     4     0           0         1         1     0
# 36        Chile         2     3   757          11         2         0     0
#
#      stripes  colours    ...     saltires  quarters  sunstars  crescent  \
# 135        3        6    ...            0         0         1         0
# 37         0        2    ...            0         0         5         0
# 116        0        7    ...            1         1         0         0
# 36         2        3    ...            0         1         1         0
#
#      triangle  icon  animate text  topleft  botright
# 135         0     1        1    1      red      blue
# 37          0     0        0    0      red       red
# 116         0     1        1    0    white      blue
# ...

# %%
tabla.sample(n=2, axis=1)[:5]
# Out:
#   topleft  area
# 0   black   648
# 1     red    29
# 2   green  2388
# 3    blue     0
# 4    blue     0

# %%
grouped = tabla[["area","religion"]].groupby("area")

# %%
for t in grouped:
    print(t)
# Out:
# (0,      area  religion
# 3       0         1
# 4       0         0
# 6       0         1
# 7       0         1
# 15      0         1
# 19      0         1
# 24      0         1
# 33      0         1
# 41      0         1
# 48      0         1
# 67      0         1
# 70      0         1
# 71      0         1
# 94      0         1
# 101     0         0
# 106     0         2
# 108     0         0
# 109     0         1
# 114     0         0
# 116     0         1
# 119     0         1
# 122     0         1
# 127     0         1
# 144     0         0
# 145     0         0
# 148     0         1
# 158     0         1
# 159     0         1
# 160     0         1
# 161     0         1
# 176     0         1
# 177     0         1
# 182     0         1
# 186     0         0)
# (1,      area  religion
# 13      1         2
# 55      1         1
# 78      1         3
# 113     1         1
# 150     1         3
# 172     1         1)
# (2,      area  religion
# 39      2         2
# ...

# %%
tabla["area"].count()
# Out:
# 194

# %%
tabla["area"].value_counts()
# Out:
# 0        34
# 1         6
# 28        3
# 2         2
# 3         2
# 4         2
# 9         2
# 11        2
# 21        2
# 10        2
# 30        2
# 36        2
# 41        2
# 268       2
# 111       2
# 128       2
# 333       2
# 18        2
# 84        2
# 2777      2
# 236       2
# 63        1
# 547       1
# 1001      1
# 43        1
# 447       1
# 301       1
# 5         1
# 47        1
# 49        1
#          ..
# 912       1
# 140       1
# 9561      1
# 905       1
# 91        1
# 587       1
# 93        1
# 98        1
# 99        1
# 2150      1
# 103       1
# 196       1
# 108       1
# 109       1
# 1247      1
# 112       1
# 113       1
# 1139      1
# 372       1
# 118       1
# 121       1
# 15        1
# 637       1
# 474       1
# 22402     1
# 132       1
# 1284      1
# 391       1
# 648       1
# 804       1
# Name: area, Length: 136, dtype: int64
