# %%
import pandas as pd
headers = ["name","landmass","zone","area","population","language","religion","bars","stripes","colours","red","green","blue","gold","white","black","orange","mainhue","circles","crosses","saltires","quarters","sunstars","crescent","triangle","icon","animate","text","topleft","botright"]
tabla = pd.read_csv("resource/flag.data",names=headers)

# %%
pd.options.display.max_columns = 2000
#pd.options.display.max_rows = 200

tabla
# Out:
#                      name  landmass  zone   area  population  language  \
# 0             Afghanistan         5     1    648          16        10
# 1                 Albania         3     1     29           3         6
# 2                 Algeria         4     1   2388          20         8
# 3          American-Samoa         6     3      0           0         1
# 4                 Andorra         3     1      0           0         6
# 5                  Angola         4     2   1247           7        10
# 6                Anguilla         1     4      0           0         1
# 7         Antigua-Barbuda         1     4      0           0         1
# 8               Argentina         2     3   2777          28         2
# 9               Argentine         2     3   2777          28         2
# 10              Australia         6     2   7690          15         1
# 11                Austria         3     1     84           8         4
# ...

# %%
tabla[(tabla["landmass"] == 5) & (tabla["name"] =="Afghanistan")]
# Out:
#           name  landmass  zone  area  population  language  religion  bars  \
# 0  Afghanistan         5     1   648          16        10         2     0
#
#    stripes  colours  red  green  blue  gold  white  black  orange mainhue  \
# 0        3        5    1      1     0     1      1      1       0   green
#
#    circles  crosses  saltires  quarters  sunstars  crescent  triangle  icon  \
# 0        0        0         0         0         1         0         0     1
#
#    animate  text topleft botright
# 0        0     0   black    green

# %%
len(tabla[(tabla["landmass"] == 5)])
# Out:
# 39

# %%
tabla["religion"].value_counts()
# Out:
# 1    60
# 0    40
# 2    36
# 5    27
# 6    15
# 3     8
# 7     4
# 4     4
# Name: religion, dtype: int64

# %%
len(tabla["religion"])
# Out:
# 194

# %%
tabla.sample(n=2)
# Out:
#                 name  landmass  zone  area  population  language  religion  \
# 185          Vanuatu         6     2    15           0         6         1
# 182  US-Virgin-Isles         1     4     0           0         1         1
#
#      bars  stripes  colours  red  green  blue  gold  white  black  orange  \
# 185     0        0        4    1      1     0     1      0      1       0
# 182     0        0        6    1      1     1     1      1      0       0
#
#     mainhue  circles  crosses  saltires  quarters  sunstars  crescent  \
# 185     red        0        0         0         0         0         0
# 182   white        0        0         0         0         0         0
#
#      triangle  icon  animate  text topleft botright
# 185         1     0        1     0   black    green
# 182         0     1        1     1   white    white

# %%
tabla.sample(n=2, axis=1)[:5]
# Out:
#    crescent  orange
# 0         0       0
# 1         0       0
# 2         1       0
# 3         0       1
# 4         0       0

# %%
total = tabla["area"].count()
total
# Out:
# 194

# %%
cantidad = tabla["area"].value_counts().sort_index()
cantidad
# Out:
# 0        34
# 1         6
# 2         2
# 3         2
# 4         2
# 5         1
# 6         1
# 9         2
# 10        2
# 11        2
# 12        1
# 15        1
# 17        1
# 18        2
# 19        1
# 21        2
# 22        1
# 23        1
# 26        1
# 28        3
# 29        1
# 30        2
# 31        1
# 36        2
# 41        2
# 43        1
# 47        1
# 49        1
# 51        1
# 57        1
#          ..
# 925       1
# 945       1
# 1001      1
# 1031      1
# 1099      1
# 1139      1
# 1221      1
# 1222      1
# 1240      1
# 1247      1
# 1267      1
# 1284      1
# 1285      1
# 1566      1
# 1648      1
# 1760      1
# 1904      1
# 1973      1
# 2150      1
# 2176      1
# 2388      1
# 2506      1
# 2777      2
# 3268      1
# 7690      1
# 8512      1
# 9363      1
# 9561      1
# 9976      1
# 22402     1
# Name: area, Length: 136, dtype: int64

# %%
len(cantidad)
# Out:
# 136

# %%
grouped = tabla[["area","religion"]].groupby(["area","religion"])
for t in grouped:
    print(t)
# Out:
# ((0, 0),      area  religion
# 4       0         0
# 101     0         0
# 108     0         0
# 114     0         0
# 144     0         0
# 145     0         0
# 186     0         0)
# ((0, 1),      area  religion
# 3       0         1
# 6       0         1
# 7       0         1
# 15      0         1
# 19      0         1
# 24      0         1
# 33      0         1
# 41      0         1
# 48      0         1
# 67      0         1
# 70      0         1
# 71      0         1
# 94      0         1
# 109     0         1
# 116     0         1
# 119     0         1
# 122     0         1
# 127     0         1
# 148     0         1
# 158     0         1
# 159     0         1
# 160     0         1
# 161     0         1
# 176     0         1
# 177     0         1
# 182     0         1)
# ((0, 2),      area  religion
# 106     0         2)
# ((1, 1),      area  religion
# 55      1         1
# 113     1         1
# 172     1         1)
# ((1, 2),     area  religion
# 13     1         2)
# ...

# %%
grouped.size()
# Out:
# area   religion
# 0      0            7
#        1           26
#        2            1
# 1      1            3
#        2            1
#        3            2
# 2      2            1
#        4            1
# 3      0            1
#        1            1
# 4      0            2
# 5      1            1
# 6      2            1
# 9      0            1
#        1            1
# 10     2            1
#        5            1
# 11     1            1
#        2            1
# 12     1            1
# 15     1            1
# 17     1            1
# 18     1            1
#        2            1
# 19     1            1
# 21     0            1
#        7            1
# 22     2            1
# 23     1            1
# 26     5            1
#                    ..
# 925    2            1
# 945    5            1
# 1001   2            1
# 1031   2            1
# 1099   0            1
# 1139   0            1
# 1221   1            1
# 1222   1            1
# 1240   2            1
# ...

# %%
grouped.size().unstack(fill_value=0)
# Out:
# religion  0   1  2  3  4  5  6  7
# area
# 0         7  26  1  0  0  0  0  0
# 1         0   3  1  2  0  0  0  0
# 2         0   0  1  0  1  0  0  0
# 3         1   1  0  0  0  0  0  0
# 4         2   0  0  0  0  0  0  0
# 5         0   1  0  0  0  0  0  0
# 6         0   0  1  0  0  0  0  0
# 9         1   1  0  0  0  0  0  0
# 10        0   0  1  0  0  1  0  0
# 11        0   1  1  0  0  0  0  0
# 12        0   1  0  0  0  0  0  0
# 15        0   1  0  0  0  0  0  0
# 17        0   1  0  0  0  0  0  0
# 18        0   1  1  0  0  0  0  0
# 19        0   1  0  0  0  0  0  0
# 21        1   0  0  0  0  0  0  1
# 22        0   0  1  0  0  0  0  0
# 23        0   1  0  0  0  0  0  0
# 26        0   0  0  0  0  1  0  0
# 28        1   0  0  0  0  2  0  0
# 29        0   0  0  0  0  0  1  0
# 30        0   1  0  0  0  1  0  0
# 31        1   0  0  0  0  0  0  0
# 36        0   0  0  1  0  1  0  0
# 41        0   2  0  0  0  0  0  0
# 43        0   1  0  0  0  0  0  0
# ...

# %%
xgroup = grouped.size().unstack(fill_value=0).sum(axis = 1)
xgroup
# Out:
# area
# 0        34
# 1         6
# 2         2
# 3         2
# 4         2
# 5         1
# 6         1
# 9         2
# 10        2
# 11        2
# 12        1
# 15        1
# 17        1
# 18        2
# 19        1
# 21        2
# 22        1
# 23        1
# 26        1
# 28        3
# 29        1
# 30        2
# 31        1
# 36        2
# 41        2
# 43        1
# 47        1
# 49        1
# 51        1
# 57        1
#          ..
# 925       1
# 945       1
# 1001      1
# 1031      1
# 1099      1
# 1139      1
# 1221      1
# 1222      1
# 1240      1
# 1247      1
# 1267      1
# 1284      1
# 1285      1
# 1566      1
# 1648      1
# 1760      1
# 1904      1
# 1973      1
# 2150      1
# 2176      1
# 2388      1
# 2506      1
# 2777      2
# 3268      1
# 7690      1
# 8512      1
# 9363      1
# 9561      1
# 9976      1
# 22402     1
# Length: 136, dtype: int64

# %%
resultado = grouped.size().unstack(fill_value=0).iloc[0,:].values
resultado
# Out:
# array([ 7, 26,  1,  0,  0,  0,  0,  0])

# %%
print(resultado.sum())
resultado = resultado /34
resultado
# Out:
# 34
# array([0.20588235, 0.76470588, 0.02941176, 0.        , 0.        ,
#        0.        , 0.        , 0.        ])

# %%
row = grouped.size().unstack(fill_value=0).iloc[0,:]
row[ row!= 0]
# Out:
# religion
# 0     7
# 1    26
# 2     1
# Name: 0, dtype: int64

# %%
len(xgroup)amount_serie
# Out:
#   File "<ipython-input-20-3a6f31157b17>", line 1
#     len(xgroup)amount_serie
#                           ^
# SyntaxError: invalid syntax

# %%
grouped.size().values

# %%
len(grouped.size().values)

# %%
tabla.sample(n=2, axis=1)[:5].join(tabla["religion"][:5])

# %%
tabla.shape[1]

# %%
isinstance(tabla,pd.DataFrame)

# %%
tabla[tabla.columns[tabla.columns != "religion"]]#.join(tabla["religion"])
#tabla.columns[tabla.columns != "religion"]

# %%
a = np.array([[1,2,3],[4,5,6]])
b = np.array([[1,2],[3,4],[5,6]])
print(a,"\n")
print(b,"\n")
a[0,:]@b[:,0]
